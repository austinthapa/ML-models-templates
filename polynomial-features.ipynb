# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')
np.random.RandomState(42)
# Out:
# RandomState(MT19937) at 0x13F5BCA40

# %%
from pandas import Series, DataFrame
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split

# %%
X = 20 * np.random.rand(1000, 1)+ np.random.normal(1000,1)
y = 3 * X + 5 + np.random.randn(1000, 1) + 4 * np.sin(X)

# %%
plt.scatter(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, train_size=0.8)

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = linear_regression.predict(X_test)

# %%
print('metrics')
print('Mean Absolute Error: ', mean_absolute_error(y_predict, y_test))
print('Mean Squared Error: ', mean_squared_error(y_predict, y_test))
# Out:
# metrics
# Mean Absolute Error:  2.5825493089343947
# Mean Squared Error:  9.008735043982396

# %%
plt.scatter(X_train, y_train, s= 15, alpha = 0.8)
plt.plot(X_test, y_predict, linewidth = 2)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('poly_features', PolynomialFeatures(degree=3)),  
    ('regressor', LinearRegression())
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('poly_features', PolynomialFeatures(degree=3)),
#                 ('regressor', LinearRegression())])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('poly_features', PolynomialFeatures(degree=3)),
#                 ('regressor', LinearRegression())])

# %%
y_predict= pipeline.predict(X_test)

# %%
print('metrics')
print('Mean Absolute Error: ', mean_absolute_error(y_predict, y_test))
print('Mean Squared Error: ', mean_squared_error(y_predict, y_test))
# Out:
# metrics
# Mean Absolute Error:  2.501285633324953
# Mean Squared Error:  8.549317515541963

# %%
plt.scatter(X, y, s = 15, alpha=0.7)
plt.plot(X_test, y_predict)

# %%
b

# %%
np.random.seed(42)
X = 10 * np.random.rand(100, 1)  # 1000 samples with one feature
noise = np.random.normal(100, 100,size = (100,1))  # Generate random noise
y = 10* X**(5/2)-1 * X**4+5 * X**3 - 3 * X**2 + 10 * X + 7 + noise # Complex cubic polynomial relationship and noise
plt.scatter(X, y, s= 15)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
poly_features = PolynomialFeatures(degree=6, include_bias=False)

# %%
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.fit_transform(X_test)

# %%
linear_reg = LinearRegression()

# %%
linear_reg.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_predict = linear_reg.predict(X_test_poly)

# %%
plt.scatter(X, y)
plt.plot(X_test,y_predict, linewidth = 2)
plt.show()
