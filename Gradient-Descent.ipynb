# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lin_reg = LinearRegression()

# %%
np.random.seed(0)
X = 2 * np.random.rand(100, 1)  # Features
y = 4 + 3 * X + np.random.randn(100, 1)  # Targets

# %%
X = np.random.uniform(0,10, size = (100,1))
y = 2 + 3 * X + 2 * np.random.randn(100,1)

# %%
plt.scatter(X, y)
plt.xlabel('Input feature')
plt.xlim(0,11)
plt.ylim(0,30)
plt.ylabel('Output feature')
plt.title('Simple Linear Regression')
plt.plot()
# Out:
# []

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, train_size=0.8)

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = lin_reg.predict(X_test)

# %%
plt.scatter(X, y)
plt.xlabel('Input feature')
plt.plot(X_test, y_predict)
plt.xlim(0,11)
plt.ylim(0,30)
plt.ylabel('Output feature')
plt.title('Simple Linear Regression')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
mean_absolute_error(y_predict, y_test)
# Out:
# 2.4816764950754804

# %%
mean_squared_error(y_predict, y_test)
# Out:
# 9.408356225786198

# %%
r2_score(y_predict, y_test)
# Out:
# 0.8691615031354101

# %%
X.shape
# Out:
# (100, 1)

# %%
theta

# %%
y.shape
# Out:
# (100, 1)

# %%
theta = 0.01

# %%
def cost_function(X, y, theta):
    m = len(y)
    prediction = X.dot(theta)
    cost = (1/2) * np.sum(np.square(prediction - y))
    return cost

# %%
def gradient_descent(X, y, theta, iterations = 1000, learning_rate = 0.01):
    for i in 
    theta  = theta - learning_rate * derivative_term
    return theta
